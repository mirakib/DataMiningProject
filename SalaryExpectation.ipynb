# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv("/content/Student_Behaviour.csv")

df
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %%
df.shape
# Out:
# (235, 19)

# %%
df.head(10)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
# 5                                                Yes
# 6                                                Yes
# 7                                                 No
# 8                                                 No
# 9                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0      65.00
# 1  Female        BCA        90.0        40.0       70.0      80.00
# 2    Male        BCA       159.0        78.0       69.5      61.00
# 3  Female        BCA       147.0        20.0       70.0      59.00
# ...

# %%
df.tail(10)
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 225                                                Yes
# 226                                                Yes
# 227                                                Yes
# 228                                                Yes
# 229                                                 No
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 225  Female   Commerce       164.0        43.0       80.0       89.0
# 226  Female   Commerce       167.0        65.0       93.0       85.0
# 227    Male  B.com ISM       167.0        55.0       55.0       57.0
# ...

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
df.isnull().sum()
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?    0
# Gender                                                                                 0
# Department                                                                             0
# Height(CM)                                                                             0
# Weight(KG)                                                                             0
# 10th Mark                                                                              0
# 12th Mark                                                                              0
# college mark                                                                           0
# hobbies                                                                                0
# daily studing time                                                                     0
# ...

# %%
del df["Height(CM)"]
del df["Weight(KG)"]

# %%
df.head(10)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
# 5                                                Yes
# 6                                                Yes
# 7                                                 No
# 8                                                 No
# 9                                                 No
#
#    Gender Department  10th Mark  12th Mark  college mark        hobbies  \
# 0    Male        BCA       79.0      65.00          80.0    Video Games
# 1  Female        BCA       70.0      80.00          70.0         Cinema
# 2    Male        BCA       69.5      61.00          55.0         Cinema
# ...

# %%
df.hist()
plt.show()

# %%
df = df.drop(['Have you completed any certification courses, or are you currently enrolled in any?', 'Gender', 'Department', 
              'hobbies', 'daily studing time', 'prefer to study in', 'Do you like your degree?', 'possibility of choosing  their career based on their degree : ', 'social medai & video games spending Time', 'Travelling Time ', 'Financial Status', 'Are you doing a part-time job right now?', 'Stress Level '], axis = 1)

# %%
sb.countplot(df["salary expectation"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.countplot(df["college mark"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
corrmat = df.corr()
sb.heatmap(corrmat, annot = True, square = True)

# %%
X = df.drop(["college mark"], axis=1)
Y = df["salary expectation"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = .30, random_state = 2)

# %%
from sklearn.linear_model import LogisticRegression
moddel=LogisticRegression()
moddel.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_predict=moddel.predict(X_test)
print("Accuracy",(moddel.score(X_test,y_test)))
# Out:
# Accuracy 0.23943661971830985

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         1
#         5000       0.00      0.00      0.00         1
#        10000       0.00      0.00      0.00         6
#        12000       0.00      0.00      0.00         2
#        13000       0.00      0.00      0.00         3
#        15000       0.00      0.00      0.00        20
#        16000       0.00      0.00      0.00         1
#        17000       0.00      0.00      0.00         1
#        18000       0.00      0.00      0.00         7
#        20000       0.24      1.00      0.39        17
#        23000       0.00      0.00      0.00         1
#        25000       0.00      0.00      0.00         4
#        30000       0.00      0.00      0.00         2
#        35000       0.00      0.00      0.00         1
#        50000       0.00      0.00      0.00         1
# ...

# %%
from sklearn.model_selection import cross_val_score
crv= cross_val_score(moddel,X,Y,cv=5)
crv

# %%
crv.mean()
# Out:
# 0.19574468085106383
